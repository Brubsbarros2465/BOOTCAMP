# %% [markdown]
# SEGUNDO NOTEBOOK DO BOOTCAMP DATASCIENCE - DADOS DO DATASUS 2008 - CADERNO DE EXPLORAÇÃO

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv", encoding= "ISO-8859-1",
                    skiprows = 3, sep=";", skipfooter = 12, thousands = ".",
                    decimal = ",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 22   43 Rio Grande do Sul        -  ...  28349257.38  1.195865e+10
# 23  50 Mato Grosso do Sul        -  ...   4059220.22  2.172158e+09
# 24         51 Mato Grosso        -  ...   6174224.99  2.036924e+09
# 25               52 Goiás        -  ...  20242641.73  4.657349e+09
# 26    53 Distrito Federal        -  ...  12044848.02  2.429933e+09
#
# [5 rows x 280 columns]

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26636409.892222222

# %%
dados.plot(x="Unidade da Federação")
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %%
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,7))

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar")

# %%
import matplotlib.pyplot as plt

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar")
ax.yaxis
plt.title("Valor por unidade da federação")
# Out:
# Text(0.5, 1.0, 'Valor por unidade da federação')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar")
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter("%d"))
plt.title("Valor por unidade da federação")
# Out:
# Text(0.5, 1.0, 'Valor por unidade da federação')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor por unidade da federação")
# Out:
# Text(0.5, 1.0, 'Valor por unidade da federação')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()

# %% [markdown]
# **PRIMEIRO DESAFIO** - ADICIONANDO UM TÍTULO MAIS DESCRITIVO AO GRÁFICO

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Gastos em internações (R$) por unidade federativada dos SUS (UF) (AGOSTO/2008)")
plt.show()

# %%
dados[["2008/Ago","2008/Set"]]
# Out:
#        2008/Ago     2008/Set
# 0    2938286.29   2843930.91
# 1    1886871.84   2084884.80
# 2    8331763.97   8148089.92
# 3    1045291.11   1003740.89
# 4   23259148.28  23667690.01
# 5    1550340.63   1550166.99
# 6    5213290.38   5201400.94
# 7   14609872.57  15317881.85
# 8   10645917.52  11037940.55
# 9   29304821.51  30435026.82
# 10  10812840.19  11258681.53
# 11  12673774.35  12790639.17
# 12  31705296.79  30703879.20
# 13   9262767.68   9228201.96
# 14   4543252.50   4525676.82
# 15  43254543.33  42851268.02
# 16  80374117.08  82400146.79
# 17  12384068.19  12486952.61
# 18  42487939.51  43066461.47
# 19 179898070.22 180082203.71
# 20  56699001.13  58091985.79
# 21  28887854.62  30725718.78
# 22  56233758.74  57910170.98
# 23   9602843.49  10272466.74
# 24   8987811.95   8843061.60
# 25  21041071.33  21396098.51
# 26  11548451.89  12422577.60

# %%
dados[["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados.mean().index
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2019/Nov', '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar', '2020/Abr',
#        '2020/Mai', '2020/Jun', '2020/Jul', 'Total'],
#       dtype='object', length=157)

# %%
colunas_usaveis = dados.mean().index

# %%
dados[colunas_usaveis]
# Out:
#      2007/Ago   2007/Set    2007/Out  ...     2020/Jun     2020/Jul          Total
# 0     4209.37   16397.03   133645.19  ...   9193593.76   7407388.24   929129659.72
# 1    10470.07   14001.71    86200.85  ...   2199920.70   1163813.08   420668039.63
# 2    35752.72   45570.64   416012.30  ...  17509334.66  13358514.02  1771654871.23
# 3     4785.91   11858.63    43852.67  ...   3216466.51   2739498.41   305010883.18
# 4   181159.29  433414.74  1893197.50  ...  35396030.78  27618727.51  4437115730.71
# 5    33672.74  104822.98   118378.28  ...   2699492.23   2155083.37   291637984.75
# 6     4113.76   76633.06   343702.61  ...   5018138.13   4489665.87   999998621.85
# 7   385330.18 1018352.93  2277717.78  ...  31128144.66  24374205.15  3632860959.84
# 8   220788.25  353468.67  1078182.68  ...  15375523.59  18019214.49  2130616492.35
# 9   357904.65  572356.18  1865065.71  ...  42146555.81  30809221.22  6197357245.98
# ...

# %%
colunas_usaveis = dados.mean().index
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2019/Nov', '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar', '2020/Abr',
#        '2020/Mai', '2020/Jun', '2020/Jul', 'Total'],
#       dtype='object', length=157)

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
dados[colunas_usaveis]
# Out:
#       Unidade da Federação   2007/Ago  ...     2020/Jul          Total
# 0              11 Rondônia    4209.37  ...   7407388.24   929129659.72
# 1                  12 Acre   10470.07  ...   1163813.08   420668039.63
# 2              13 Amazonas   35752.72  ...  13358514.02  1771654871.23
# 3               14 Roraima    4785.91  ...   2739498.41   305010883.18
# 4                  15 Pará  181159.29  ...  27618727.51  4437115730.71
# 5                 16 Amapá   33672.74  ...   2155083.37   291637984.75
# 6             17 Tocantins    4113.76  ...   4489665.87   999998621.85
# 7              21 Maranhão  385330.18  ...  24374205.15  3632860959.84
# 8                 22 Piauí  220788.25  ...  18019214.49  2130616492.35
# 9                 23 Ceará  357904.65  ...  30809221.22  6197357245.98
# 10  24 Rio Grande do Norte  134605.36  ...  19593057.45  2477372149.60
# 11              25 Paraíba   97352.78  ...  15491469.06  2470550104.25
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Jul         Total
# 0          11 Rondônia   4209.37  ...  7407388.24  929129659.72
# 1              12 Acre  10470.07  ...  1163813.08  420668039.63
# 2          13 Amazonas  35752.72  ... 13358514.02 1771654871.23
# 3           14 Roraima   4785.91  ...  2739498.41  305010883.18
# 4              15 Pará 181159.29  ... 27618727.51 4437115730.71
#
# [5 rows x 158 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   7407388.24   929129659.72
# 12 Acre                  10470.07   14001.71  ...   1163813.08   420668039.63
# 13 Amazonas              35752.72   45570.64  ...  13358514.02  1771654871.23
# 14 Roraima                4785.91   11858.63  ...   2739498.41   305010883.18
# 15 Pará                 181159.29  433414.74  ...  27618727.51  4437115730.71
# 16 Amapá                 33672.74  104822.98  ...   2155083.37   291637984.75
# 17 Tocantins              4113.76   76633.06  ...   4489665.87   999998621.85
# 21 Maranhão             385330.18 1018352.93  ...  24374205.15  3632860959.84
# 22 Piauí                220788.25  353468.67  ...  18019214.49  2130616492.35
# 23 Ceará                357904.65  572356.18  ...  30809221.22  6197357245.98
# ...

# %%
usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
usaveis = usaveis.drop("Total", axis=1)

# %%
usaveis.T
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37   10470.07  ...   179395.82            191951.47
# 2007/Set                 16397.03   14001.71  ...   418053.58            769966.25
# 2007/Out                133645.19   86200.85  ...  1198730.25           2165619.56
# 2007/Nov                346912.84  301323.68  ...  2712117.54           3813256.48
# 2007/Dez                711758.31  769612.36  ...  9293914.78           7121965.42
# ...                           ...        ...  ...         ...                  ...
# 2020/Mar               7174312.31 2859102.06  ... 34558308.52          19405446.88
# 2020/Abr               7423678.64 2472063.08  ... 27499307.93          18123899.78
# 2020/Mai               8581195.13 2383895.48  ... 31870107.62          21437430.22
# 2020/Jun               9193593.76 2199920.70  ... 34437633.20          23479773.03
# ...

# %%
usaveis.T.plot(figsize=(10, 6))

# %% [markdown]
# PRIMEIRO DESAFIO AULA 2 - REPOSICIONAR A LEGENDA DO GRAFICO

# %%
usaveis.T.plot(figsize=(10, 6))
plt.legend(title = "Estados(UF)", bbox_to_anchor = (1.50 , 1))
plt.show()

# %% [markdown]
# PLOTAR O GRAFICO PARA 5 ESTADOS

# %%
estados_desejados = ['31 Minas Gerais', '33 Rio de Janeiro','32 Espírito Santo', '35 São Paulo', '53 Distrito Federal']
estados_desejados
# Out:
# ['31 Minas Gerais',
#  '33 Rio de Janeiro',
#  '32 Espírito Santo',
#  '35 São Paulo',
#  '53 Distrito Federal']

# %%
ax2 = usaveis.loc[estados_desejados].T.plot(figsize = (12,6))
ax2.yaxis.set_major_formatter(ticker.StrMethodFormatter("R$ {x:.2f}"))
plt.show()

# %%
usaveis.T.plot(figsize=(10, 6))
plt.legend(title = "Estados(UF)", bbox_to_anchor = (1.50 , 1))
plt.show()

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[1:4]
# Out:
# Index(['12 Acre', '13 Amazonas', '14 Roraima'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   9193593.76   7407388.24
# 12 Acre                  10470.07   14001.71  ...   2199920.70   1163813.08
# 13 Amazonas              35752.72   45570.64  ...  17509334.66  13358514.02
# 14 Roraima                4785.91   11858.63  ...   3216466.51   2739498.41
# 15 Pará                 181159.29  433414.74  ...  35396030.78  27618727.51
# 16 Amapá                 33672.74  104822.98  ...   2699492.23   2155083.37
# 17 Tocantins              4113.76   76633.06  ...   5018138.13   4489665.87
# 21 Maranhão             385330.18 1018352.93  ...  31128144.66  24374205.15
# 22 Piauí                220788.25  353468.67  ...  15375523.59  18019214.49
# 23 Ceará                357904.65  572356.18  ...  42146555.81  30809221.22
# 24 Rio Grande do Norte  134605.36  272088.08  ...  20219961.81  19593057.45
# ...

# %%
usaveis[:5].T.plot(figsize = (12,6))

# %%
ax = usaveis[:7].T.plot(figsize=(10,6))

# %%
usaveis.sample(n=7)
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 41 Paraná             554800.22 1431708.01  ...  92901461.36  80320852.69
# 27 Alagoas            104243.75  174024.90  ...  14278872.07  13087850.40
# 31 Minas Gerais       971394.37 2861781.50  ... 135977571.87 120467187.34
# 17 Tocantins            4113.76   76633.06  ...   5018138.13   4489665.87
# 12 Acre                10470.07   14001.71  ...   2199920.70   1163813.08
# 25 Paraíba             97352.78  368130.43  ...  19666096.87  15491469.06
# 50 Mato Grosso do Sul 199556.12  573675.41  ...  15838659.34  12508717.35
#
# [7 rows x 156 columns]

# %%
import numpy as np
np.random.seed(687942)

usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  27450865.16  27460475.47
# 31 Minas Gerais        971394.37 2861781.50  ... 135977571.87 120467187.34
# 24 Rio Grande do Norte 134605.36  272088.08  ...  20219961.81  19593057.45
# 17 Tocantins             4113.76   76633.06  ...   5018138.13   4489665.87
# 53 Distrito Federal    191951.47  769966.25  ...  23479773.03  22233542.26
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  15838659.34  12508717.35
# 16 Amapá                33672.74  104822.98  ...   2699492.23   2155083.37
#
# [7 rows x 156 columns]

# %%
usaveis.sum(axis=1)
# Out:
# Unidade da Federação
# 11 Rondônia                925572673.82
# 12 Acre                    420666755.81
# 13 Amazonas               1766925554.09
# 14 Roraima                 303485991.45
# 15 Pará                   4425537480.57
# 16 Amapá                   290781699.72
# 17 Tocantins               997507241.35
# 21 Maranhão               3621885105.60
# 22 Piauí                  2122676207.29
# 23 Ceará                  6182786402.04
# 24 Rio Grande do Norte    2469235766.39
# 25 Paraíba                2461941658.63
# 26 Pernambuco             8013135105.77
# 27 Alagoas                2097903424.04
# 28 Sergipe                1128585323.09
# 29 Bahia                  9167733691.21
# 31 Minas Gerais          19102100731.94
# 32 Espírito Santo         3128353199.69
# 33 Rio de Janeiro         9659938007.12
# 35 São Paulo             38779063638.12
# 41 Paraná                13745248985.60
# 42 Santa Catarina         7306969709.51
# 43 Rio Grande do Sul     11930181093.98
# ...

# %%
usaveis["Total"] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  925572673.82
# 12 Acre               10470.07  14001.71  ...  1163813.08  420666755.81
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1766925554.09
# 14 Roraima             4785.91  11858.63  ...  2739498.41  303485991.45
# 15 Pará              181159.29 433414.74  ... 27618727.51 4425537480.57
#
# [5 rows x 157 columns]

# %%
usaveis.sort_values("Total")
# Out:
#                          2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                          ...
# 16 Amapá                 33672.74  104822.98  ...   2155083.37   290781699.72
# 14 Roraima                4785.91   11858.63  ...   2739498.41   303485991.45
# 12 Acre                  10470.07   14001.71  ...   1163813.08   420666755.81
# 11 Rondônia               4209.37   16397.03  ...   7407388.24   925572673.82
# 17 Tocantins              4113.76   76633.06  ...   4489665.87   997507241.35
# 28 Sergipe               27453.63   78565.19  ...   3312766.32  1128585323.09
# 13 Amazonas              35752.72   45570.64  ...  13358514.02  1766925554.09
# 51 Mato Grosso           63562.50  232444.62  ...  13083151.70  2030739826.14
# 27 Alagoas              104243.75  174024.90  ...  13087850.40  2097903424.04
# 22 Piauí                220788.25  353468.67  ...  18019214.49  2122676207.29
# ...

# %%
usaveis.sort_values("Total", ascending=False)
# Out:
#                          2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                          ...
# 35 São Paulo           1665349.90 4434168.64  ... 282709570.31 38779063638.12
# 31 Minas Gerais         971394.37 2861781.50  ... 120467187.34 19102100731.94
# 41 Paraná               554800.22 1431708.01  ...  80320852.69 13745248985.60
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  78929703.81 11930181093.98
# 33 Rio de Janeiro       469469.34  921646.57  ...  71540227.33  9659938007.12
# 29 Bahia                135146.36  448349.75  ...  58898100.40  9167733691.21
# 26 Pernambuco           400640.85 1088340.42  ...  62325444.34  8013135105.77
# 42 Santa Catarina       693955.05 1092964.12  ...  51764534.76  7306969709.51
# 23 Ceará                357904.65  572356.18  ...  30809221.22  6182786402.04
# 52 Goiás                179395.82  418053.58  ...  33499284.38  4637039055.60
# ...

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending=False) 
ordenado_por_total = ordenado_por_total.drop(["Total"], axis=1)
ordenado_por_total.head(2)
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 299060851.62 282709570.31
# 31 Minas Gerais       971394.37 2861781.50  ... 135977571.87 120467187.34
#
# [2 rows x 156 columns]

# %%
usaveis[:7].T.plot(figsize=(10,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
estados_desafio_2 = ordenado_por_total.loc[['35 São Paulo', '33 Rio de Janeiro', '41 Paraná', '26 Pernambuco', '29 Bahia']]
ax = estados_desafio_2.T.plot(xlabel = ('Ano/Mês'), ylabel=('Gasto Reais (R$)'), figsize = (8,6), title=('Gastos com o SUS nos estados de SP, RJ, PR, PE e BA'),
                              cmap=plt.get_cmap('Accent'))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.show()

# %% [markdown]
# Desafio 02: Adicionar uma coluna mostrando a região (Norte, Nodeste, Sul, Suldeste e Centro-Oeste) de cada estado.

# %%
regioes = []
for estados in usaveis.index:
  if estados.startswith('1'):
    regioes.append('Norte')
  elif estados.startswith('2'):
    regioes.append('Nordeste')
  elif estados.startswith('3'):
    regioes.append('Sudeste')
  elif estados.startswith('4'):
    regioes.append('Sul')
  else:
    regioes.append('Centro-Oeste')

usaveis.insert(0, 'Regiões', regioes)

usaveis
# Out:
#                              Regiões   2007/Ago  ...     2020/Jul          Total
# Unidade da Federação                             ...
# 11 Rondônia                    Norte    4209.37  ...   7407388.24   925572673.82
# 12 Acre                        Norte   10470.07  ...   1163813.08   420666755.81
# 13 Amazonas                    Norte   35752.72  ...  13358514.02  1766925554.09
# 14 Roraima                     Norte    4785.91  ...   2739498.41   303485991.45
# 15 Pará                        Norte  181159.29  ...  27618727.51  4425537480.57
# 16 Amapá                       Norte   33672.74  ...   2155083.37   290781699.72
# 17 Tocantins                   Norte    4113.76  ...   4489665.87   997507241.35
# 21 Maranhão                 Nordeste  385330.18  ...  24374205.15  3621885105.60
# 22 Piauí                    Nordeste  220788.25  ...  18019214.49  2122676207.29
# 23 Ceará                    Nordeste  357904.65  ...  30809221.22  6182786402.04
# ...

# %% [markdown]
# Desafio 03: Formatar o gráfico de custos por mês dos 5 estados, deixando ele agradável (Bonitão, segundo o Gui)

# %%
ax = ordenado_por_total[:5].T.plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
xlim_l = 0
xlim_r = len(ordenado_por_total.columns) - 1
ylim_lower = ordenado_por_total[:5].min().min()*0.9
ylim_upper = ordenado_por_total.max().max()*1.11
plt.xlim(xlim_l, xlim_r)
plt.ylim(ylim_lower, ylim_upper)
plt.legend(loc='upper left', ncol=2)

# %% [markdown]
# Desafio 04: Adicione o seu estado aos 5 estados plotados anteriormente

# %%
# O estado onde moro é RJ e já estava no gráfico, então adicionei Amazonas
# variável criada com os 5 estados que mais gastaram
cinco_mais_gatos = ordenado_por_total.head(5) 

# variável criada com o resultado do Amazaronas, buscando nos dados ordenados por gasto
Amazonas = ordenado_por_total.loc['13 Amazonas'] 

top5_gastos_am = cinco_mais_gatos.append(Amazonas) 

top5_gastos_am.T.plot(figsize = (8, 6))

# %% [markdown]
# Desafio 05: Buscar os casos de dengue no Brasil (época de maior número de casos e regiões mais atingidas) e se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de dengue

# %%
ordenado_por_total.head(5).T.plot(figsize = (10, 8))
plt.legend(bbox_to_anchor = (1,1))

# %% [markdown]
# Nesses links podemos observar que esses fatos se confirman em 2013 os casos de denguem aumentaram 190%
# http://g1.globo.com/bemestar/noticia/2013/02/casos-de-dengue-no-pais-aumentam-190-no-comeco-de-2013-diz-governo.html
# E no ano de 2016 apresentamos o pior surto de de dengue dos ultimos 10 anos como mostra esse outro link
# https://www.em.com.br/app/noticia/gerais/2016/12/30/interna_gerais,836096/balanco-de-2016-mostra-pior-epidemia-de-dengue-dos-ultimos-10-anos.shtml

# %% [markdown]
# Desafio 06: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região

# %%
regiao =  {'1':'Norte',
           '2':'Nordeste',
           '3':'Sudeste',
           '4':'Sul',
           '5':'Centro-Oeste'}
function = lambda x: regiao[x.name[0]]
usaveis['Região'] = usaveis.apply(function, axis=1)

# %%
usaveis["Total"] = usaveis.sum(axis=1) #incluindo novamente a coluna TOTAL
usaveis.head()
# Out:
#                      Regiões  2007/Ago  ...         Total  Região
# Unidade da Federação                    ...
# 11 Rondônia            Norte   4209.37  ... 1851145347.64   Norte
# 12 Acre                Norte  10470.07  ...  841333511.62   Norte
# 13 Amazonas            Norte  35752.72  ... 3533851108.18   Norte
# 14 Roraima             Norte   4785.91  ...  606971982.90   Norte
# 15 Pará                Norte 181159.29  ... 8851074961.14   Norte
#
# [5 rows x 159 columns]

# %%
sudeste = usaveis.loc[usaveis['Região'] == 'Sudeste']


sudeste = sudeste.drop(['Região'], axis=1)

sudeste
# Out:
#                       Regiões   2007/Ago  ...     2020/Jul          Total
# Unidade da Federação                      ...
# 31 Minas Gerais       Sudeste  971394.37  ... 120467187.34 38204201463.88
# 32 Espírito Santo     Sudeste   57408.11  ...  27460475.47  6256706399.38
# 33 Rio de Janeiro     Sudeste  469469.34  ...  71540227.33 19319876014.24
# 35 São Paulo          Sudeste 1665349.90  ... 282709570.31 77558127276.24
#
# [4 rows x 158 columns]

# %%
comparativo_2 = sudeste.index.to_list()
comparativo_2.append("13 Amazonas")
comparativo_2
# Out:
# ['31 Minas Gerais',
#  '32 Espírito Santo',
#  '33 Rio de Janeiro',
#  '35 São Paulo',
#  '13 Amazonas']

# %%
sudeste_am = usaveis.loc[comparativo_2]

sudeste_am = sudeste_am.drop(['Região'], axis=1)


sudeste_am
# Out:
#                       Regiões   2007/Ago  ...     2020/Jul          Total
# Unidade da Federação                      ...
# 31 Minas Gerais       Sudeste  971394.37  ... 120467187.34 38204201463.88
# 32 Espírito Santo     Sudeste   57408.11  ...  27460475.47  6256706399.38
# 33 Rio de Janeiro     Sudeste  469469.34  ...  71540227.33 19319876014.24
# 35 São Paulo          Sudeste 1665349.90  ... 282709570.31 77558127276.24
# 13 Amazonas             Norte   35752.72  ...  13358514.02  3533851108.18
#
# [5 rows x 158 columns]

# %%
sns.set_palette(sns.color_palette("gist_rainbow", 6))

sudeste_am.T.plot  ## NAO CONSEGUI PLOTAR NAO APARECEU OS DADOS

plt.title("Comparativo entre SUDESTE e AMAZONAS", fontsize=32)
plt.xlabel("Ano / Mês", fontsize=15)
plt.ylabel("X milhões de Reais", fontsize=15)
plt.legend(title="UF", bbox_to_anchor = (1.30, 1), frameon=True)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import seaborn as sns
sns.set_palette(sns.color_palette("gist_rainbow", 6))

sudeste_am.T.plot  ## NAO CONSEGUI PLOTAR NAO APARECEU OS DADOS
 

plt.title("Estados da região Sudeste", fontsize=15)
plt.xlabel("Ano / Mês", fontsize=15)
plt.ylabel("X milhões de Reais", fontsize=15)
plt.legend(title="UF", bbox_to_anchor = (1.30, 1), frameon=True)
plt.grid(color='b', linestyle='-', linewidth=0.4)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
ordenado_por_total[ordenado_por_total.columns[47:]].head(3).T.plot(figsize=(10,6))

# %%
meses_filtrados = ordenado_por_total.columns[47:150] 
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(100, 350)
# Out:
# (100.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-24:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-36:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-60:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total.head(5).T.plot(figsize=(6,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(6,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(20,6))

# %% [markdown]
# Desafio 01: Refaça as manipulações feitas em aulas e gaste um tempo analisando os dados e entendendo os efeitos das manipulações
#
# Com a manipulação dos gráficos como mudanças de eixo x e y e a manipulação de largura e altura, conseguimos gerar falsa interpretação aos nossos olhos. Causando assim toda uma análise erradas de números em seu projeto.
#
# Desafio 02: Reflita sobre os problemas na manipulação de dados e discuta esse assunto no Discord
# Quando trabalhamos com a manipulação de dados é de grande importancia os manipular de forma correta pois qualquer erro que seja, pode acarretar um grande errado no seu resultado final.
